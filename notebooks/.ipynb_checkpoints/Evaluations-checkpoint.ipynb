# %% [markdown]
# # Experiments

# %% [markdown]
# - Try to make the feature binary instead of having floating point to see its impact on performance.
# -

# %%
# import matplotlib.pyplot as plt
# %matplotlib inline

# df = pd.read_csv('logs_oracle_verySmall')
# df[df['skip_decision'] == 1]

# df.tail()
# # Lets analyze for student 1
# df[df['skip_decision']== 1] 
# df[df['student_number'] == 1]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# df_oracle = pd.read_csv('logs_oracle_verySmall')
df_oracle = pd.read_csv('logs_oracle_verySmall')
df_linUCB = pd.read_csv('logs_linUCB_verySmall')

df_linUCB[df_linUCB['student_number'] == 12]
# Out:
#      student_number topic arm_pulled  pay-off  pay-off_next_topic  \
# 47               12   T_1     C_1_15     0.34                0.34
# 91               12   T_1     C_1_14     0.38                0.29
# 146              12   T_1     C_1_13     0.46                0.28
# 229              12   T_2     C_2_20     0.28                0.28
# 275              12   T_2     C_2_17     0.25                0.28
# 328              12   T_3     C_3_13     0.34                0.39
# 358              12   T_3     C_3_11     0.38                0.39
# 390              12   T_3     C_3_10     0.35                0.35
# 419              12   T_3      C_3_4     0.27                0.36
# 447              12   T_3      C_3_9     0.27                0.35
# 502              12   T_4      C_4_3     0.38                0.29
# 541              12   T_4      C_4_4     0.39                0.29
# 581              12   T_4      C_4_2     0.49                0.30
# 619              12   T_4      C_4_1     0.69                0.28
# 662              12   T_4      C_4_5     1.00                0.28
# 721              12   T_5     C_5_13     0.28                0.34
# 775              12   T_6      C_6_9     0.32                0.29
# 810              12   T_6      C_6_8     0.34                0.32
# 851              12   T_6      C_6_4     0.31                0.32
# 898              12   T_7     C_7_13     0.32                0.40
# 945              12   T_8      C_8_6     0.40                0.25
# 980              12   T_9     C_9_15     0.24                0.45
# 985              12   T_9     C_9_19     0.24                0.45
# 993              12  T_10     C_10_5     0.45                0.00
# 995              12  T_10     C_10_3     0.39                0.00
#
#      actual_decision  skip_decision  reward  confidence_score  expected_reward
# 47                 0              0       0        -22.884456         0.420847
# 91                 0              0       0        -33.083437         0.414728
# 146                1              0       1         23.671791         0.549621
# 229                0              0       0        -25.466700         0.424585
# 275                1              0       1          6.426144         0.400714
# 328                0              0       0         -5.799535         0.344417
# 358                1              0       0         23.573700         0.470787
# 390                0              0       0        -38.558064         0.496826
# 419                0              0       0        -29.896419         0.550279
# 447                0              0       1         -1.099814         0.533779
# 502                0              0       0         -6.120468         0.385835
# 541                1              0       0         25.436622         0.429570
# 581                1              0       0         24.409170         0.352809
# 619                1              0       0         16.485670         0.439872
# 662                0              0       1         -4.475904         0.454820
# 721                0              0       1         -5.218384         0.472891
# 775                1              0       0         15.584337         0.497152
# 810                1              0       0          8.821494         0.322497
# 851                0              0       1         -2.833343         0.504069
# 898                1              0       1         31.471369         0.417943
# 945                1              0       1         18.299838         0.436856
# 980                0              0       0        -20.691056         0.548520
# 985                0              0       1        -25.761669         0.471944
# 993                0              0       0        -11.066396         0.380329
# 995                1              0       1          1.236192         0.354419

# %% [markdown]
# ## Cumulative rewards

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df_oracle = pd.read_csv('logs_oracle_verySmall')
df_linUCB_0001 = pd.read_csv('logs_linUCB_verySmall_0.001')
df_linUCB_05 = pd.read_csv('logs_linUCB_verySmall_0.5')
df_linUCB_2 = pd.read_csv('logs_linUCB_verySmall_2')

# Find the reward accumulate over rounds 
cum_reward_oracle = np.cumsum(df_oracle['reward'])
cum_reward_linUCB_0001 = np.cumsum(df_linUCB_0001['reward'])
cum_reward_linUCB_05 = np.cumsum(df_linUCB_05['reward'])
cum_reward_linUCB_2 = np.cumsum(df_linUCB_2['reward'])

plt.plot(list(cum_reward_oracle.index),cum_reward_oracle,color='r',label='Omniscient Policy')
plt.plot(list(cum_reward_linUCB_0001.index),cum_reward_linUCB_0001,color='g',label='Teach With LinUCB alpha=0.001')
plt.plot(list(cum_reward_linUCB_05.index),cum_reward_linUCB_05,color='b',label='Teach With LinUCB alpha=0.5')
plt.plot(list(cum_reward_linUCB_2.index),cum_reward_linUCB_2,color='black',label='Teach With LinUCB alpha=2')
# Find the reward accumulate over rounds 
# cum_reward = np.cumsum(df['reward'])
# plt.plot(list(cum_reward.index),cum_reward,color='r',label='Oracle')
plt.xlabel('Rounds')
plt.ylabel('Rewards')
plt.legend(loc='upper left')
plt.title('Cumulative reward over rounds')
plt.savefig('cum_reward.png')
plt.show()

# %%
# df = pd.read_csv('logs_linUCB_verySmall')
# # Find the reward accumulate over rounds 
# cum_reward = np.cumsum(df['reward'])
# plt.plot(list(cum_reward.index),cum_reward,color='b',label='Teach With LinUCB')

# %% [markdown]
# ## Find Challenging Topics

# %%
df_oracle['topic'].value_counts().plot(kind='barh')

# %% [markdown]
# ## Student Progression

# %%
s = pd.Series([2, 0, 4, 8, np.nan])
s.between(1, 4)
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
student_progression = df_linUCB['student_number'].value_counts()

student_progression_10_to_15 = len(student_progression[student_progression.between(left = 10 , right = 15)])
student_progression_16_to_20 = len(student_progression[student_progression.between(left = 16 , right = 20)])
student_progression_21_to_25 = len(student_progression[student_progression.between(left = 21 , right = 25)])
student_progression_26_to_30 = len(student_progression[student_progression.between(left = 26 , right = 30)])
student_progression_31_to_35 = len(student_progression[student_progression.between(left = 31 , right = 35)])
student_progression_36_to_40 = len(student_progression[student_progression.between(left = 36 , right = 40)])

X = pd.Series(['10-15','16-20','21-25','26-30','31-35','36-40'])
Y = pd.Series([student_progression_10_to_15,student_progression_16_to_20,student_progression_21_to_25,student_progression_26_to_30,
              student_progression_31_to_35,student_progression_36_to_40])
plt.bar(X,Y)
plt.xlabel('Rounds')
plt.ylabel('Students')
#plt.legend(loc='upper right')
plt.title('Rounds needed by students')
#plt.savefig('cum_reward.png')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Rounds to complete a course

# %%
# How many rounds did it take for a student to complete the course. 
rounds_per_student = df_linUCB['student_number'].value_counts()
rounds_per_student.value_counts()
rounds_per_student.value_counts().plot(kind='barh')

# %% [markdown]
# ## Round per topic for a student to complete the course.

# %%
df_student = df_linUCB[df_linUCB['student_number'] == 3]
df_student['topic'].value_counts()
# Out:
# T_9     5
# T_2     4
# T_8     4
# T_7     4
# T_6     1
# T_5     1
# T_4     1
# T_3     1
# T_10    1
# T_1     1
# Name: topic, dtype: int64

# %% [markdown]
# ## Efficacy of Content

# %%
# Usefulness / Efficacy of the content presented. For project show top 5 most effective & most ineffective to paint a picture. 

df_linUCB.tail()
reward_per_arm = df_linUCB[['arm_pulled','reward']]
reward_per_arm.groupby(["arm_pulled", "reward"]).size()
# Out:
# arm_pulled  reward
# C_10_1      0          3
#             1          1
# C_10_2      0          4
#             1          4
# C_10_3      0          8
#             1          6
# C_10_4      0         14
#             1         15
# C_10_5      0         29
#             1         21
# C_1_10      1          2
# C_1_11      0          2
#             1          2
# C_1_12      0          4
#             1          3
# C_1_13      0          7
#             1          6
# C_1_14      0         13
#             1         15
# C_1_15      0         28
#             1         22
# C_2_14      1          1
# C_2_15      0          1
#             1          5
# C_2_16      0          6
#             1          2
# C_2_17      0          8
#             1          6
# C_2_18      0         10
#             1         10
#                       ..
# C_7_11      0          4
#             1          1
# C_7_12      0          5
#             1          5
# C_7_13      0         10
#             1         17
# C_7_14      0         27
#             1         23
# C_7_8       1          2
# C_7_9       0          2
#             1          1
# C_8_2       0          1
#             1          3
# C_8_3       0          4
#             1          1
# C_8_4       0          5
#             1         12
# C_8_5       0         16
#             1         11
# C_8_6       0         27
#             1         23
# C_9_15      1          2
# C_9_16      0          2
#             1          3
# C_9_17      0          5
#             1          5
# C_9_18      0          9
#             1         12
# C_9_19      0         20
#             1         28
# Length: 115, dtype: int64

# %% [markdown]
# ## Skipping Algorithm

# %% [markdown]
# Lets start to find
#
# 1) Performance of skip classifier
# 2) Optimal confidence threshold
# 3) Is the need for having a confidence threshold justified ?
#
# If the performance of the classifier is better with a threshold, then yes, the need is justified.
#
# 4)
#
# ORACLE
#
# For CT = 20 over verySmall
#
# sc_success : 346 , sc_failure : 329 , sc_ct_success : 378, sc_ct_failure : 297 , total : 675
# success : 25 and failure : 30
#
# actual_decision  skip_decision  reward
# 0                0              0.0       189
#                                 1.0       238
# 1                0              0.0       108
#                                 1.0       140
#                  1              0.0        42
#                                 1.0        55
#
# For CT = 10 over verySmall
#
# sc_success : 289 , sc_failure : 243 , sc_ct_success : 308, sc_ct_failure : 224 , total : 532
# success : 55 and failure : 36
#
# actual_decision  skip_decision  reward
# 0                0              0.0       173
#                                 1.0       238
# 1                0              0.0        51
#                                 1.0        70
#                  1              0.0        66
#                                 1.0        73
#
# For CT = 0 over verySmall
#
# sc_success : 269 , sc_failure : 172 , sc_ct_success : 308, sc_ct_failure : 224 , total : 441
# success : 54 and failure : 27
#
# actual_decision  skip_decision  reward
# 0                0              0.0       172
#                                 1.0       269
# 1                1              0.0        93
#                                 1.0       109

# %%
df_oracle = pd.read_csv('logs_oracle_verySmall_CT0')
df_1 = df_oracle[["actual_decision","skip_decision","reward"]]
perf_data = df_1.groupby(["actual_decision","skip_decision","reward"]).size()
perf_data_groupby = df_1.groupby(["actual_decision","skip_decision","reward"])
perf_data
# Out:
# actual_decision  skip_decision  reward
# 0                0              0.0       172
#                                 1.0       269
# 1                1              0.0        93
#                                 1.0       109
# dtype: int64

# %%
sc_success = len(perf_data_groupby.get_group((0,0,1.0))) + len(perf_data_groupby.get_group((1,0,0.0))) 
# sc_success = len(perf_data_groupby.get_group((0,0,1.0))) 
sc_failure = len(perf_data_groupby.get_group((0,0,0.0))) + len(perf_data_groupby.get_group((1,0,0.0))) 
sc_ct_success = len(perf_data_groupby.get_group((0,0,1.0))) + len(perf_data_groupby.get_group((1,0,1.0))) 
sc_ct_failure = len(perf_data_groupby.get_group((0,0,0.0))) + len(perf_data_groupby.get_group((1,0,0.0))) 
total = sc_success + sc_failure
print('sc_success : {0} , sc_failure : {1} , sc_ct_success : {2}, sc_ct_failure : {3} , total : {4} '.format(sc_success,sc_failure,sc_ct_success,sc_ct_failure,total))
# type(obj)
# type(df_1)
# Out:
# sc_success : 269 , sc_failure : 172 , sc_ct_success : 308, sc_ct_failure : 224 , total : 441

# %%
#df_oracle[df_oracle['reward'].isnull()]
#df_oracle_student_0 = df_oracle[df_oracle['student_number'] == 0]
success = 0
failure = 0
topic_skipped = False
for index , row in df_oracle.iterrows():
    if row['reward'] not in [0.0,1.0]:
        topic_skipped = True
        continue
    if topic_skipped:
        if row['reward'] == 0:
            failure += 1
        if row['reward'] == 1:
            success += 1
        topic_skipped = False
print('success : {0} and failure : {1}'.format(success,failure))
# Out:
# success : 54 and failure : 27

# %%
nan_var = df_oracle_student_0.loc[86,'reward']
if nan_var not in [0.0,1.0]:
    print(nan_var)
# Out:
# nan

# %%
# Out:
#      student_number topic arm_pulled  pay-off  pay-off_next_topic  \
# 0                 0   T_1     C_1_13     0.58                0.60
# 50                0   T_1      C_1_3     0.56                0.60
# 86                0   T_1     C_1_11     0.54                0.60
# 164               0   T_2      C_2_5     0.60                0.67
# 222               0   T_3      C_3_5     0.67                0.51
# 273               0   T_4      C_4_1     0.51                0.56
# 315               0   T_4      C_4_4     0.50                0.56
# 371               0   T_5      C_5_3     0.56                0.61
# 429               0   T_6      C_6_4     0.61                0.65
# 480               0   T_7      C_7_8     0.65                0.53
# 543               0   T_8      C_8_4     0.53                0.61
# 607               0   T_9     C_9_17     0.61                0.52
# 634               0  T_10     C_10_1     0.52                0.00
#
#      actual_decision  skip_decision  reward  confidence_score
# 0                  0              0     0.0        -10.000000
# 50                 0              0     0.0        -33.188709
# 86                 1              1     NaN         36.766122
# 164                0              0     1.0        -36.600003
# 222                1              1     1.0         25.042789
# 273                0              0     0.0         -8.523859
# 315                0              0     1.0        -23.866927
# 371                1              0     1.0         11.046854
# 429                0              0     1.0         -1.803931
# 480                0              0     1.0         -3.973760
# 543                0              0     1.0        -12.600315
# 607                1              1     1.0         26.064969
# 634                1              1     1.0         26.638873

# %%
df_linUCB_student = df_linUCB[df_linUCB['student_number'] == 0]
skipped_count = 0
#df_linUCB_student[df_linUCB_student['reward'].isnull()]
for j in df_linUCB_student:
    print(j['reward'])
#     if j['reward'].isnull():
#         skipped_count+=1
# skipped_count
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-82d3b650185e> in <module>
#       3 #df_linUCB_student[df_linUCB_student['reward'].isnull()]
#       4 for j in df_linUCB_student:
# ----> 5     print(j['reward'])
#       6 #     if j['reward'].isnull():
#       7 #         skipped_count+=1
#
# TypeError: string indices must be integers

# %%
# How well does the skipping algorithm perform. There are 2 parts to it
# If the skip decision is 0 , we have the data readily available 
# df_linUCB = pd.read_csv('logs_linUCB_verySmall')
# Based on actual decision

# df_1 = df_linUCB[["actual_decision","skip_decision","reward"]]
# df_1.groupby(["actual_decision","skip_decision","reward"]).size()
# df_1.head()

# What happens in the round after we decide to skip
# success = 0
# failure = 0
# df_1 = df_oracle.copy()
# students = df_1.student_number.unique()
# for s in students[:1]:
#     s_df = df_1[df_1['student_number'] == s]
#     # Condition 1: 
#     if s_df['actual_decision'] == 0 and s_df['reward'] == 0:
    
# Find all unique students 
    # For each student find corresponding entries in datadrame & sort by index. 
      # Add conditions to find number of correct prediction versus number of incorrect predictions. 
        
# df_1[df_1['student_number'] == 8]

# df_1.groupby(['reward']).size()

#df_1 = df_1[["actual_decision","skip_decision","reward"]]


# If the skip decision is 1, then whether that was the right decision, depends on the reward for obtained immediately 
# after skipping. So we need to sort the data by student_number & topic. 
# df_copy = df_linUCB.copy()
# df_copy.sort_values(['student_number', 'topic'], ascending=[True, True])

import pandas as pd 
df_linUCB = pd.read_csv('logs_linUCB_small')
df_linUCB_student = df_linUCB[df_linUCB['student_number'] == 2]
success = 0
failure = 0 
topic_skipped = False
for i in df_linUCB_student:
    if i['reward'] not in [0.0,1.0]: 
        topic_skipped = True
        continue
    if topic_skipped:
        if i['reward'] == 0:
            failure += 1
        if i['reward'] == 1:
            success += 1
        topic_skipped = False
print('success {0} & failures {1}'.format(success,failure))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-5219b5807ff0> in <module>
#      41 topic_skipped = False
#      42 for i in df_linUCB_student:
# ---> 43     if i['reward'] not in [0.0,1.0]:
#      44         topic_skipped = True
#      45         continue
#
# TypeError: string indices must be integers

# %%
# How well does the skipping algorithm perform. There are 2 parts to it
# If the skip decision is 0 , we have the data readily available 
df_linUCB = pd.read_csv('logs_linUCB_verySmall')
# Based on actual decision

df_1 = df_linUCB[["actual_decision","reward"]]
df_1.groupby(["actual_decision","reward"]).size()
# df_1.head()
# Out:
# actual_decision  reward
# 0                0         283
#                  1         234
# 1                0         262
#                  1         262
# dtype: int64

# %%
# How well does the skipping algorithm perform 
# Ans : 

df_linUCB

# How does the performance improve because we're using confidence threshold

# What should be the optimal value for confidence threshold

#

# %% [markdown]
# # Optimal value of $\alpha$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# df_oracle = pd.read_csv('logs_oracle_verySmall')

df_linUCB_1 = pd.read_csv('logs_linUCB_verySmall_alpha0.5')
df_linUCB_2 = pd.read_csv('logs_linUCB_verySmall_alpha2')
df_oracle = pd.read_csv('logs_oracle_verySmall')
# Find the reward accumulate over rounds 
cum_reward_oracle = np.cumsum(df_oracle['reward'])
cum_reward_linUCB_1 = np.cumsum(df_linUCB_1['reward'])
cum_reward_linUCB_2 = np.cumsum(df_linUCB_2['reward'])
plt.plot(list(cum_reward_oracle.index),cum_reward_oracle,color='r',label='Omniscient Policy')
plt.plot(list(cum_reward_linUCB_1.index),cum_reward_linUCB_1,color='g',label='LinUCB with alpha=0.5')
plt.plot(list(cum_reward_linUCB_2.index),cum_reward_linUCB_2,color='b',label='LinUCB with alpha=2')
# Find the reward accumulate over rounds 
# cum_reward = np.cumsum(df['reward'])
# plt.plot(list(cum_reward.index),cum_reward,color='r',label='Oracle')
plt.xlabel('Rounds')
plt.ylabel('Rewards')
plt.legend(loc='upper left')
plt.title('Cumulative reward over rounds')
plt.savefig('cum_reward_compare_alphas.png')
plt.show()

# %%
import pandas as pd
df_linUCB_1 = pd.read_csv('logs_linUCB_verySmall_alpha0.5')
df_linUCB_2 = pd.read_csv('logs_linUCB_verySmall_alpha2')
df_oracle = pd.read_csv('logs_oracle_verySmall')
df_oracle.head()
# Out:
#    student_number topic arm_pulled  pay-off  pay-off_next_topic  \
# 0               0   T_1     C_1_12     0.58                0.56
# 1               1   T_1     C_1_13     0.57                0.59
# 2              19   T_1      C_1_3     0.51                0.59
# 3              39   T_1      C_1_3     0.64                0.65
# 4               6   T_1      C_1_3     0.63                0.60
#
#    actual_decision  skip_decision  reward  confidence_score
# 0                0              0       0        -10.000000
# 1                0              0       1        -10.000000
# 2                0              0       1        -11.093822
# 3                0              0       1         -5.137735
# 4                0              0       1        -14.249511
